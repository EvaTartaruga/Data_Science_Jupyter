# %% [markdown]
# # <center>Folium Practices  </center>

# %% [markdown]
# ### Importing Libraries

# %%
#basic
import pandas as pd
import numpy as np
import plotly.express as px

#read enconding
import chardet

#url requests
import urllib.request

# geospatial
import folium
from folium import plugins

# %% [markdown]
# <br>
#
# ## Fetching Data

# %% [markdown]
# ### About Dataset
#
# Two kind of data sets were used in this notebook.
#
# * External semi-automatic defibrillators located outside the healthcare environment Dataset"*
# * New cases of cancer by autonomous communities in the last year
#
# <br>
#
# Sources:
#
# * https://abertos.xunta.gal/busca-de-datos
#
# * https://www.epdata.es/datos/cancer-espana-datos-estadisticas/289?accion=3
#
# * https://github.com/codeforgermany/click_that_hood/blob/main/public/data/spain-communities.geojson

# %% [markdown]
# <br>
#
# **External semi-automatic defibrillators located outside the healthcare environment Dataset"**
#
# From: https://abertos.xunta.gal/catalogo/saude-servicios-sociais/-/dataset/0604/desfibriladores-semiautomaticos-externos-situados
#
# Semi-automatic external defibrillators, also known as DESA, are a medical product intended to analyze the heart rhythm, identify fatal arrhythmias requiring defibrillation and administer an electric shock with the aim of restoring a viable heart rhythm with high levels of safety.
#
# This is how Decree 38/2017, dated March 23, defines it, which regulates its installation and use in the healthcare field in Galicia, also creating the Registry of External Defibrillators in Galicia.
#
# The file contains information collected in this record in relation to:
#
# * or registration number of each defibrillator
# * to a public or private entity that requests
# * or place where it is found (postal address and geographical coordinates)
# * or type of facility not available (administrations or public institutions, pilgrim hostels, airports, stations, educational centers, private companies, sports facilities, municipal swimming pools...).

# %%
#pip install chardet

# %%
#to detecet encoding and read from a csv file in the local computer

# Detecting encoding 
with open("./equipos-DESA-061.csv", 'rb') as f:
    result = chardet.detect(f.read())

encoding_detected = result['encoding']
print(f"Encoding detectado: {encoding_detected}")

#read
data_DESA = pd.read_csv("./equipos-DESA-061.csv", encoding=encoding_detected)

data_DESA.head()
# Out:
# Encoding detectado: Windows-1252
#    codequipo                      solicitante  \
# 0       1002            USC (Campus Santiago)
# 1       1003               Aeropuerto de Vigo
# 2       1010  Deputación Provincial da Coruña
# 3       1012     Showa Denko Carbón Spain, SA
# 4       1020             PC Concello A Coruña
#
#                                            ubicacion  municipio   provincia  \
# 0                   Enfermaría Piscina Universitaria   SANTIAGO    A CORUÑA
# 1                                  Aeroporto de Vigo       VIGO  PONTEVEDRA
# 2                                       Teatro Colón  CORUÑA, A    A CORUÑA
# 3  Showa Denko Carbón Spain (junto al servicio mé...  CORUÑA, A    A CORUÑA
# 4                                        Praia Lapas  CORUÑA, A    A CORUÑA
#
#        lat     lon              tipoInstalacion
# 0  42.8780 -8.5552          En centros docentes
# 1  42.2257 -8.6328  En aeropuertos o estaciones
# 2  43.3702 -8.3986                        Otros
# 3  43.3450 -8.4335           En empresa privada
# 4  43.3836 -8.4062   Protección civil (no amb.)

# %% [markdown]
# <br>
#
# **New cases of cancer by autonomous communities in the last year**
#
# From:https://www.epdata.es/nuevos-casos-cancer-cada-100000-personas-comunidades-autonomas/37a78337-e295-45f8-8ba1-70dea98075c3
#
# GEOJson: https://github.com/codeforgermany/click_that_hood/blob/main/public/data/spain-communities.geojson
#
# This Dataset represents the cases detected in the last year (2022) per 100,000 inhabitants.

# %%
#to detecet encoding and read from a csv file in the local computer

# Detecting encoding 
with open("./spain_cancer.csv", 'rb') as f:
    result = chardet.detect(f.read())

encoding_detected = result['encoding']
print(f"Encoding detectado: {encoding_detected}")


#read
data_cancer = pd.read_csv("./spain_cancer.csv", encoding=encoding_detected, sep=';')

data_cancer.head()
# Out:
# Encoding detectado: UTF-8-SIG
#     Año Periodo  Parámetro Nuevos casos detectados de cáncer
# 0  2022     Año  Andalucía                            567,27
# 1  2022     Año     Aragón                            665,67
# 2  2022     Año   Asturias                            764,67
# 3  2022     Año   Canarias                            545,18
# 4  2022     Año  Cantabria                            681,11

# %% [markdown]
# <br>
#
# ### Get Familiar with Data

# %% [markdown]
# **External semi-automatic defibrillators located outside the healthcare environment Dataset"**

# %%
#No null object, 7 columns
data_DESA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1606 entries, 0 to 1605
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   codequipo        1606 non-null   int64
#  1   solicitante      1606 non-null   object
#  2   ubicacion        1606 non-null   object
#  3   municipio        1606 non-null   object
#  4   provincia        1606 non-null   object
#  5   lat              1606 non-null   float64
#  6   lon              1606 non-null   float64
#  7   tipoInstalacion  1606 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 100.5+ KB

# %%
data_DESA.shape
# Out:
# (1606, 8)

# %% [markdown]
# <br>
#
# **New cases of cancer by autonomous communities in the last year**

# %%
#change name columns 
data_cancer.rename(columns={'Parámetro':'province', 'Nuevos casos detectados de cáncer':'cancer_cases'}, inplace=True)
data_cancer.head()
# Out:
#     Año Periodo   province cancer_cases
# 0  2022     Año  Andalucía       567,27
# 1  2022     Año     Aragón       665,67
# 2  2022     Año   Asturias       764,67
# 3  2022     Año   Canarias       545,18
# 4  2022     Año  Cantabria       681,11

# %%
#Spain have 29 countries, so there are more rows
data_cancer.shape
# Out:
# (33, 4)

# %%
data_cancer
# Out:
#                                                   Año Periodo  \
# 0                                                2022     Año
# 1                                                2022     Año
# 2                                                2022     Año
# 3                                                2022     Año
# 4                                                2022     Año
# 5                                                2022     Año
# 6                                                2022     Año
# 7                                                2022     Año
# 8                                                2022     Año
# 9                                                2022     Año
# 10                                               2022     Año
# 11                                               2022     Año
# 12                                               2022     Año
# 13                                               2022     Año
# 14                                               2022     Año
# 15                                               2022     Año
# 16                                               2022     Año
# 17                                               2022     Año
# 18                                               2022     Año
# 19                                                NaN     NaN
# 20                                                NaN     NaN
# 21        Métrica:"Nuevos casos detectados de cáncer"     NaN
# 22      Fuente:"Asociación Española Contra el Cáncer"     NaN
# 23                                   Clasificación:""     NaN
# 24    Unidad:"Casos clínicos de cáncer diagnosticado"     NaN
# 25                                  Escala:"Unidades"     NaN
# 26                         EscalaFactorPotencia10:"0"     NaN
# 27                           SonDatosNumericos:"True"     NaN
# 28                                                NaN     NaN
# 29                                                NaN     NaN
# 30  Url:"https://www.epdata.es/nuevos-casos-cancer...     NaN
# 31  Titulo:"Casos de cáncer por cada 100.000 perso...     NaN
# 32                                       Subtitulo:""     NaN
#
#                 province cancer_cases
# 0              Andalucía       567,27
# 1                 Aragón       665,67
# 2               Asturias       764,67
# 3               Canarias       545,18
# 4              Cantabria       681,11
# 5        Castilla y León       759,65
# 6     Castilla-La Mancha       606,98
# 7              Catalunya       594,49
# 8                  Ceuta       452,85
# 9   Comunidad Valenciana        609,3
# 10           Extremadura          661
# 11               Galicia       740,02
# 12        Islas Baleares       509,22
# 13              La Rioja        657,5
# 14                Madrid       561,88
# 15               Melilla       426,28
# 16                Murcia       527,25
# 17               Navarra       619,34
# 18            País Vasco       687,81
# 19                   NaN          NaN
# 20                   NaN          NaN
# 21                   NaN          NaN
# 22                   NaN          NaN
# 23                   NaN          NaN
# 24                   NaN          NaN
# 25                   NaN          NaN
# 26                   NaN          NaN
# 27                   NaN          NaN
# 28                   NaN          NaN
# 29                   NaN          NaN
# 30                   NaN          NaN
# 31                   NaN          NaN
# 32                   NaN          NaN

# %%
# We only need from row 0 to 18 included
df_cancer=data_cancer.loc[0:18,:]
df_cancer.shape
# Out:
# (19, 4)

# %%
df_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           19 non-null     object
#  1   Periodo       19 non-null     object
#  2   province      19 non-null     object
#  3   cancer_cases  19 non-null     object
# dtypes: object(4)
# memory usage: 736.0+ bytes

# %%
#change dtype to float
df_cancer.loc[:, 'cancer_cases'] = df_cancer['cancer_cases'].str.replace(',', '.').astype(float)

df_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Año           19 non-null     object
#  1   Periodo       19 non-null     object
#  2   province      19 non-null     object
#  3   cancer_cases  19 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 736.0+ bytes
# C:\Users\evama\AppData\Local\Temp\ipykernel_21008\2705314925.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cancer.loc[:, 'cancer_cases'] = df_cancer['cancer_cases'].str.replace(',', '.').astype(float)
# C:\Users\evama\AppData\Local\Temp\ipykernel_21008\2705314925.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_cancer.loc[:, 'cancer_cases'] = df_cancer['cancer_cases'].str.replace(',', '.').astype(float)

# %%
#change province names to have the same as GeoJson
df_cancer['province'].unique()
# Out:
# array(['Andalucía', 'Aragón', 'Asturias', 'Canarias', 'Cantabria',
#        'Castilla y León', 'Castilla-La Mancha', 'Catalunya', 'Ceuta',
#        'Comunidad Valenciana', 'Extremadura', 'Galicia', 'Islas Baleares',
#        'La Rioja', 'Madrid', 'Melilla', 'Murcia', 'Navarra', 'País Vasco'],
#       dtype=object)

# %%
df_cancer.replace({'Andalucía':'Andalucia', 'Aragón':'Aragon', 'Castilla y León':'Castilla-Leon', 
                     'Comunidad Valenciana':'Valencia', 'Islas Baleares':'Baleares', 'País Vasco':'Pais Vasco' }, inplace=True)
df_cancer.head()
# Out:
# C:\Users\evama\AppData\Local\Temp\ipykernel_21008\970728275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cancer.replace({'Andalucía':'Andalucia', 'Aragón':'Aragon', 'Castilla y León':'Castilla-Leon',
#     Año Periodo   province  cancer_cases
# 0  2022     Año  Andalucia        567.27
# 1  2022     Año     Aragon        665.67
# 2  2022     Año   Asturias        764.67
# 3  2022     Año   Canarias        545.18
# 4  2022     Año  Cantabria        681.11

# %% [markdown]
# <br>
#
# ### Introduction to Folium

# %%
#Galicia Map

Galicia_map=folium.Map(location=[42.755, -7.866111], zoom_start=8, tiles="OpenStreetMap")

Galicia_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_d135e89525de4d1289c7f575992be676 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d135e89525de4d1289c7f575992be676&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_d135e89525de4d1289c7f575992be676 = L.map(
#                                   &#x27;map_d135e89525de4d1289c7f575992be676&#x27;,
#                                   {center: [42.755,-7.866111],
#                                   zoom: 8,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_0573e5f4e481e6101d053b9848dd462b = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_d135e89525de4d1289c7f575992be676);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>
#
# ### Map with Markers

# %% [markdown]
# Visualize locations of DESA in Galicia

# %%
# let's start again with a clean copy of the map 
Galicia_map=folium.Map(location=[42.755, -7.866111], zoom_start=8, tiles="OpenStreetMap")


# instantiate a mark cluster object for the DESA in the dataframe
DESA = plugins.MarkerCluster().add_to(Galicia_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(data_DESA.lat, data_DESA.lon, data_DESA.tipoInstalacion):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(DESA)

# display map
Galicia_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_bf417a28e82510f72fec69924bdcd9e2 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf417a28e82510f72fec69924bdcd9e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_bf417a28e82510f72fec69924bdcd9e2 = L.map(
#                                   &#x27;map_bf417a28e82510f72fec69924bdcd9e2&#x27;,
#                                   {center: [42.755,-7.866111],
#                                   zoom: 8,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_f9d14d43b0bc4c6b8b35f00a14440370 = L.tileLayer(
#                 &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_bf417a28e82510f72fec69924bdcd9e2);
#
#
#             var marker_cluster_9e48d91942671242bdf60e5354d10100 = L.markerClusterGroup({
#
#             });
#             map_bf417a28e82510f72fec69924bdcd9e2.addLayer(marker_cluster_9e48d91942671242bdf60e5354d10100);
#
#
#
#             var marker_7c061422355a9f5fe8d7e53bf69d8c67 = L.marker(
#                 [42.878,-8.5552],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_9e48d91942671242bdf60e5354d10100);
#
#
#             var popup_4979e6c4b7f470ee3a2c981ff1694d38 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_8ce2d93810aa6f429781a82574366099 = $(&#x27;&lt;div id=&quot;html_8ce2d93810aa6f429781a82574366099&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;En centros docentes&lt;/div&gt;&#x27;)[0];
#                 popup_4979e6c4b7f470ee3a2c981ff1694d38.setContent(html_8ce2d93810aa6f429781a82574366099);
#
#
#             marker_7c061422355a9f5fe8d7e53bf69d8c67.bindPopup(popup_4979e6c4b7f470ee3a2c981ff1694d38);
#
#
#
#
#
#             var marker_64a96f5d0135194fa1ec483c81d7eb9e = L.marker(
#                 [42.2257,-8.6328],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_9e48d91942671242bdf60e5354d10100);
#
#
#             var popup_5f07f7972e464c38da70752046285f99 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_c073056042971ca475024d2b380305fc = $(&#x27;&lt;div id=&quot;html_c073056042971ca475024d2b380305fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;En aeropuertos o estaciones&lt;/div&gt;&#x27;)[0];
#                 popup_5f07f7972e464c38da70752046285f99.setContent(html_c073056042971ca475024d2b380305fc);
#
#
#             marker_64a96f5d0135194fa1ec483c81d7eb9e.bindPopup(popup_5f07f7972e464c38da70752046285f99);
#
#
#
#
#
#             var marker_3c5a45ce2e19203850b884f37e484695 = L.marker(
#                 [43.3702,-8.3986],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_9e48d91942671242bdf60e5354d10100);
#
#
#             var popup_4b80e793d87516462b9485fa29bae310 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_2618778c2bad63333f55eecffa327501 = $(&#x27;&lt;div id=&quot;html_2618778c2bad63333f55eecffa327501&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Otros&lt;/div&gt;&#x27;)[0];
#                 popup_4b80e793d87516462b9485fa29bae310.setContent(html_2618778c2bad63333f55eecffa327501);
#
#
#             marker_3c5a45ce2e19203850b884f37e484695.bindPopup(popup_4b80e793d87516462b9485fa29bae310);
#
#
#
#
#
#             var marker_08ad058619bbbca817f7d3d6299a026a = L.marker(
#                 [43.345,-8.4335],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_9e48d91942671242bdf60e5354d10100);
#
#
#             var popup_2278f686f720da84d89410e70644d269 = L.popup({maxWidth: &#x27;300&#x27;});
#
#
#                 var html_4eb5739e40b27b5a6aacb8e718b84711 = $(&#x27;&lt;div id=&quot;html_4eb5739e40b27b5a6aacb8e718b84711&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;En empresa privada&lt;/div&gt;&#x27;)[0];
#                 popup_2278f686f720da84d89410e70644d269.setContent(html_4eb5739e40b27b5a6aacb8e718b84711);
#
#
#             marker_08ad058619bbbca817f7d3d6299a026a.bindPopup(popup_2278f686f720da84d89410e70644d269);
#
#
#
#
#
#             var marker_33b2dea9de2388a77019fb26408193d4 = L.marker(
#                 [43.3836,-8.4062],
#                 {
#                     icon: new L.Icon.Default()
#                     }
#                 )
#                 .addTo(marker_cluster_9e48d91942671242bdf60e5354d10100);

# %% [markdown]
# <br>
#
# ### Choropleth Maps

# %% [markdown]
# Cases of cancer in 2022 by province in Spain

# %%
# geoJson file
spain_geo_path = './spain-communities.geojson'

# %%
scale=list(range(400, 801, 75))
scale
# Out:
# [400, 475, 550, 625, 700, 775]

# %%
# create a plain world map
spain_map = folium.Map(location=[37.5, -4], zoom_start=5, tiles='Cartodb positron')

# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
spain_map.choropleth(
    geo_data=spain_geo_path, 
    data=df_cancer,
    columns=['province', 'cancer_cases'],
    key_on='feature.properties.name',
    fill_color='OrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Cases of cancer per 10000 inhabitants in 2022',
    #threshold_scale=scale,
    reset=True
)


# display map
spain_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#             &lt;style&gt; #map_865b992613b093f9bff765301910826e {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_865b992613b093f9bff765301910826e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#
#
#                 var bounds = null;
#
#
#             var map_865b992613b093f9bff765301910826e = L.map(
#                                   &#x27;map_865b992613b093f9bff765301910826e&#x27;,
#                                   {center: [37.5,-4],
#                                   zoom: 5,
#                                   maxBounds: bounds,
#                                   layers: [],
#                                   worldCopyJump: false,
#                                   crs: L.CRS.EPSG3857
#                                  });
#
#
#
#             var tile_layer_7efb504508fa2ec870795e391a25ab17 = L.tileLayer(
#                 &#x27;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&#x27;,
#                 {
#   &quot;attribution&quot;: null,
#   &quot;detectRetina&quot;: false,
#   &quot;maxZoom&quot;: 18,
#   &quot;minZoom&quot;: 1,
#   &quot;noWrap&quot;: false,
#   &quot;subdomains&quot;: &quot;abc&quot;
# }
#                 ).addTo(map_865b992613b093f9bff765301910826e);
#
#
#
#
#
#                 var geo_json_a3dc06c92797481e0e7c63b5d5bea12a = L.geoJson(
#                     {&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-4.893577, 43.238479], [-4.839201, 43.18976], [-4.851778, 43.17307], [-4.834567, 43.157463], [-4.851426, 43.125945], [-4.816903, 43.092658], [-4.766497, 43.074547], [-4.766114, 43.055633], [-4.743985, 43.05645], [-4.739274, 43.022276], [-4.638131, 43.016673], [-4.606084, 43.035767], [-4.558449, 43.019515], [-4.520932, 43.047368], [-4.475713, 43.038702], [-4.462752, 43.060535], [-4.447551, 43.05854], [-4.398114, 43.034868], [-4.348485, 42.972581], [-4.240249, 42.956533], [-4.236703, 42.917112], [-4.222565, 42.910978], [-4.224679, 42.85677], [-4.199694, 42.844571], [-4.181202, 42.858694], [-4.14426, 42.868615], [-4.128477, 42.846267], [-4.140447, 42.829002], [-4.178566, 42.826247], [-4.185429, 42.817297], [-4.182704, 42.810346], [-4.149915, 42.789309], [-4.098486, 42.791182], [-4.07173, 42.760537], [-4.045912, 42.766611], [-4.050217, 42.779801], [-4.014183, 42.806377], [-4.007441, 42.831112], [-3.999652, 42.768979], [-3.978885, 42.758081], [-3.910953, 42.768386], [-3.894446, 42.804538], [-3.863375, 42.786458], [-3.822211, 42.799638], [-3.826742, 42.870857], [-3.863736, 42.88981], [-3.880189, 42.851386], [-3.914832, 42.860084], [-3.897473, 42.880285], [-3.924349, 42.889221], [-3.892934, 42.887363], [-3.910584, 42.910926], [-3.907819, 42.914523], [-3.868605, 42.899076], [-3.833546, 42.917986], [-3.839539, 42.93978], [-3.887383, 42.948767], [-3.891277, 42.925485], [-3.933543, 42.899602], [-3.929987, 42.914849], [-3.974617, 42.912353], [-3.987171, 42.94054], [-3.945465, 43.005773], [-3.909261, 43.016097], [-3.890746, 43.041826], [-3.850786, 43.039248], [-3.831769, 43.063826], [-3.846961, 43.084399], [-3.764569, 43.081034], [-3.754882, 43.100548], [-3.704677, 43.116275], [-3.651753, 43.180792], [-3.612449, 43.169518], [-3.603544, 43.149637], [-3.444756, 43.131533], [-3.388867, 43.140003], [-3.253417, 43.198581], [-3.224093, 43.170132], [-3.148292, 43.174001], [-3.141362, 43.161538], [-3.181786, 43.120879], [-3.133941, 43.097234], [-3.158187, 43.074016], [-3.140312, 43.06715], [-3.14186, 43.029814], [-3.177802, 43.021984], [-3.060257, 43.00351], [-3.041475, 42.969921], [-2.981262, 42.93912], [-3.018906, 42.908512], [-3.092102, 42.898779], [-3.149273, 42.917063], [-3.144732, 42.934682], [-3.224729, 42.949692], [-3.248545, 42.912145], [-3.277239, 42.90158], [-3.282609, 42.875514], [-3.205533, 42.827401], [-3.222176, 42.838636], [-3.190686, 42.869463], [-3.162823, 42.856737], [-3.11494, 42.889249], [-3.11315, 42.861064], [-3.159229, 42.804591], [-3.123255, 42.789326], [-3.147913, 42.756697], [-3.049654, 42.765606], [-3.04201, 42.73952], [-3.016953, 42.741084], [-2.980631, 42.703819], [-2.931358, 42.708402], [-2.902502, 42.693603], [-2.89606, 42.655033], [-2.858093, 42.638205], [-2.916008, 42.619521], [-2.946451, 42.639317], [-3.084152, 42.640687], [-3.05983, 42.589188], [-3.134271, 42.542053], [-3.072572, 42.528923], [-3.094695, 42.488074], [-3.046004, 42.445154], [-3.063299, 42.42491], [-3.056881, 42.370273], [-3.082652, 42.397384], [-3.078179, 42.41575], [-3.101347, 42.416777], [-3.10527, 42.386369], [-3.084811, 42.385386], [-3.063462, 42.356697], [-3.109668, 42.351448], [-3.088589, 42.245725], [-3.129368, 42.198494], [-3.034373, 42.085963], [-2.935333, 42.089408], [-2.913624, 42.022852], [-2.883826, 42.009487], [-2.797986, 42.046844], [-2.803344, 42.080484], [-2.774851, 42.123536], [-2.734666, 42.124954], [-2.705947, 42.103556], [-2.757377, 42.033102], [-2.746961, 42.009275], [-2.579909, 41.996264], [-2.549067, 42.05151], [-2.51488, 42.068861], [-2.514676, 42.114542], [-2.484369, 42.106349], [-2.438462, 42.137268], [-2.318205, 42.145181], [-2.28216, 42.131703], [-2.269589, 42.088555], [-2.208883, 42.104661], [-2.127324, 42.097169], [-2.12724, 42.080462], [-2.161913, 42.066734], [-2.107632, 42.002774], [-2.124072, 41.995309], [-2.109961, 41.957868], [-2.036392, 41.939404], [-2.028314, 41.953386], [-1.970298, 41.919142], [-1.855916, 41.96629 ...

# %%
df_cancer
# Out:
#      Año Periodo            province  cancer_cases
# 0   2022     Año           Andalucia        567.27
# 1   2022     Año              Aragon        665.67
# 2   2022     Año            Asturias        764.67
# 3   2022     Año            Canarias        545.18
# 4   2022     Año           Cantabria        681.11
# 5   2022     Año       Castilla-Leon        759.65
# 6   2022     Año  Castilla-La Mancha        606.98
# 7   2022     Año           Catalunya        594.49
# 8   2022     Año               Ceuta        452.85
# 9   2022     Año            Valencia        609.30
# 10  2022     Año         Extremadura        661.00
# 11  2022     Año             Galicia        740.02
# 12  2022     Año            Baleares        509.22
# 13  2022     Año            La Rioja        657.50
# 14  2022     Año              Madrid        561.88
# 15  2022     Año             Melilla        426.28
# 16  2022     Año              Murcia        527.25
# 17  2022     Año             Navarra        619.34
# 18  2022     Año          Pais Vasco        687.81

# %% [markdown]
# <br>
#
# # Author
#
# <a>Eva Villar Álvarez</a>
#
# 2024/02/05
#
# <br>
#
#  **Change Log**
#
# | Date (YYYY-MM-DD) | Version |      Change Description                                   |
# | ----------------- | ------- |---------------------------------------------------------- |
